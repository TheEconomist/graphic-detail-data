# %%
# This script takes the PRIO/COW data and UCDP data, and identifies how many deaths each country suffered in each year
# It also includes some extra data for the Iraq and Afghanistan wars

# %%
import pandas as pd
import numpy as np
import datetime
import dateutil.parser
import re
from tqdm import tqdm_notebook
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Step 1: import datasets, prepare columns and functions ##

# %%
conflict_years_df = pd.read_csv("output_data/conflict_years_df.csv") # Dataframe containing years and death tolls for each conflict

# %%
# PRIO/COW dataframes containing the overall death tolls for each country in each conflict, between 1900 and 1997
COW_interstate_country_df = pd.read_csv("source_data/PRIO_conflict_data/PRIO_2.0_interstate_country_data.csv")
COW_intrastate_country_df = pd.read_csv("source_data/PRIO_conflict_data/PRIO_2.0_intrastate_country_data.csv")
COW_extrastate_country_df = pd.read_csv("source_data/PRIO_conflict_data/PRIO_2.0_extrastate_country_data.csv")

# %%
# UCDP dataframe containing the death tolls for each country in each conflict incident, between 1989 and 2017
UCDP_all_df = pd.read_csv("source_data/UCDP_conflict_data/UCDP_18.1_incident_data.csv",encoding="latin1")
# Out:
# C:\Users\jamestozer\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# This dataframe lists all countries that have Maddison economic data and Polity regime data, with both Maddison and COW codes
country_converter_df = pd.read_csv("source_data/maddison_economic_data/country_converter.csv")
country_converter_df.set_index("gwn_id",drop=True,inplace=True)
country_converter_df
# Out:
#              participant_country participant_region participant_maddison_code
# gwn_id
#  700.0               Afghanistan        Middle East                       AFG
#  339.0                   Albania             Europe                       ALB
#  615.0                   Algeria             Africa                       DZA
#  540.0                    Angola             Africa                       AGO
#  160.0                 Argentina           Americas                       ARG
#  371.0                   Armenia             Europe                       ARM
#  900.0                 Australia               Asia                       AUS
#  305.0                   Austria             Europe                       AUT
#  300.0    Austria (with Hungary)             Europe                       AUT
#  373.0                Azerbaijan             Europe                       AZE
#  692.0                   Bahrain        Middle East                       BHR
#  771.0                Bangladesh               Asia                       BGD
# NaN                     Barbados           Americas                       BRB
#  370.0                   Belarus             Europe                       BLR
#  211.0                   Belgium             Europe                       BEL
#  434.0                     Benin             Africa                       BEN
#  145.0                   Bolivia           Americas                       BOL
#  346.0        Bosnia-Herzegovina             Europe                       BIH
#  571.0                  Botswana             Africa                       BWA
#  140.0                    Brazil           Americas                       BRA
#  355.0                  Bulgaria             Europe                       BGR
#  439.0              Burkina Faso             Africa                       BFA
#  516.0                   Burundi             Africa                       BDI
#  402.0                Cabo Verde             Africa                       CPV
#  811.0                  Cambodia               Asia                       KHM
#  471.0                  Cameroon             Africa                       CMR
#  20.0                     Canada           Americas                       CAN
#  482.0  Central African Republic             Africa                       CAF
#  483.0                      Chad             Africa                       TCD
#  155.0                     Chile           Americas                       CHL
# ...                          ...                ...                       ...
#  380.0                    Sweden             Europe                       SWE
#  225.0               Switzerland             Europe                       CHE
#  652.0                     Syria        Middle East                       SYR
#  713.0                    Taiwan               Asia                       TWN
#  702.0                Tajikistan               Asia                       TJK
#  510.0                  Tanzania             Africa                       TZA
#  800.0                  Thailand               Asia                       THA
#  461.0                      Togo             Africa                       TGO
#  52.0        Trinidad and Tobago           Americas                       TTO
#  616.0                   Tunisia             Africa                       TUN
#  640.0                    Turkey             Europe                       TUR
#  701.0              Turkmenistan               Asia                       TKM
#  500.0                    Uganda             Africa                       UGA
#  369.0                   Ukraine             Europe                       UKR
#  696.0      United Arab Emirates        Middle East                       ARE
#  200.0            United Kingdom             Europe                       GBR
#  2.0    United States of America           Americas                       USA
#  165.0                   Uruguay           Americas                       URY
#  364.0                      USSR             Europe                       SUN
#  704.0                Uzbekistan               Asia                       UZB
#  101.0                 Venezuela           Americas                       VEN
#  818.0                   Vietnam               Asia                       VNM
#  816.0           Vietnam (North)               Asia                       DRV
#  817.0           Vietnam (South)               Asia                       RVN
#  679.0                     Yemen        Middle East                       YEM
#  678.0             Yemen (North)        Middle East                       YAR
#  680.0             Yemen (South)        Middle East                       YPR
#  345.0                Yugoslavia             Europe                       YUG
#  551.0                    Zambia             Africa                       ZMB
#  552.0       Zimbabwe (Rhodesia)             Africa                       ZWE
#
# [181 rows x 3 columns]

# %%
# Columns used for initial dataframe
country_conflicts_columns = ["participant_country","participant_country_id","participant_maddison_code",
"participant_region","participant_deaths","conflict_name","conflict_start_year","conflict_end_year","COW_id","UCDP_id","state_conflict_type"]

# %%
# Columns used for final dataframe
country_conflict_year_columns = country_conflicts_columns + ["year","year_deaths_share","year_deaths"]

# %% [markdown]
# ## Step 2: clean Correlates of War data ##

# %%
# Function that gets the last year of a COW conflict ("yrend1" sometimes indicates a break in the conflict, rather than the end)
def get_COW_end_year(COW_df):
    end_year_list = []
    for i,r in COW_df.iterrows():
        if r["yrend2"] > 0:
            end_year_list.append(r["yrend2"])
        else:
            end_year_list.append(r["yrend1"])
    COW_df["yrend_last"] = end_year_list

# %%
get_COW_end_year(COW_interstate_country_df)
get_COW_end_year(COW_intrastate_country_df)
get_COW_end_year(COW_extrastate_country_df)

# %%
# Use country_converter_df to join Maddison codes and region to COW dataframe
COW_interstate_country_df = COW_interstate_country_df[["statenum","pbdeadbest","warname","yrbeg1","yrend_last","warno"]]
COW_interstate_country_df.columns = ["participant_country_id","participant_deaths","conflict_name","conflict_start_year","conflict_end_year","COW_id"]
COW_interstate_country_df = COW_interstate_country_df.join(country_converter_df,on="participant_country_id")
COW_interstate_country_df["UCDP_id"] = None
COW_interstate_country_df["state_conflict_type"] = "Interstate"
COW_interstate_country_df = COW_interstate_country_df[country_conflicts_columns] # Keep only relevant columns
COW_interstate_country_df
# Out:
#           participant_country  participant_country_id  \
# 0                       China                     710
# 1                        USSR                     364
# 2                       Japan                     740
# 3              United Kingdom                     200
# 4    United States of America                       2
# 5                      France                     220
# 6                        USSR                     364
# 7                       China                     710
# 8                        USSR                     364
# 9                       Japan                     740
# 10                   Honduras                      91
# 11                El Salvador                      92
# 12                  Guatemala                      90
# 13                El Salvador                      92
# 14                  Nicaragua                      93
# 15                   Honduras                      91
# 16                      Spain                     230
# 17                    Morocco                     600
# 18                      Italy                     325
# 19                     Turkey                     640
# 20                 Yugoslavia                     345
# 21                     Turkey                     640
# 22                   Bulgaria                     355
# 23                     Greece                     350
# 24                 Yugoslavia                     345
# 25                     Greece                     350
# 26                   Bulgaria                     355
# 27                    Romania                     360
# 28                     Turkey                     640
# 29                     Greece                     350
# ..                        ...                     ...
# 165                      Cuba                      40
# 166                   Somalia                     520
# 167                  Ethiopia                     530
# 168                    Uganda                     500
# 169                  Tanzania                     510
# 170                     Libya                     620
# 171                     China                     710
# 172           Vietnam (North)                     816
# 173                      Iran                     630
# 174                      Iraq                     645
# 175                 Argentina                     160
# 176            United Kingdom                     200
# 177                     Syria                     652
# 178                    Israel                     666
# 179           Vietnam (North)                     816
# 180                     China                     710
# 181                      Iraq                     645
# 182                      Oman                     698
# 183      United Arab Emirates                     696
# 184                     Qatar                     694
# 185                    Kuwait                     690
# 186              Saudi Arabia                     670
# 187                     Egypt                     651
# 188                   Morocco                     600
# 189                     Italy                     325
# 190                    France                     220
# 191            United Kingdom                     200
# 192                    Canada                      20
# 193  United States of America                       2
# 194                     Syria                     652
#
#     participant_maddison_code participant_region  participant_deaths  \
# 0                         CHN               Asia                2000
# 1                         SUN             Europe                 302
# 2                         JPN               Asia                 622
# 3                         GBR             Europe                  34
# 4                         USA           Americas                  21
# 5                         FRA             Europe                  24
# 6                         SUN             Europe                 242
# 7                         CHN               Asia                3758
# 8                         SUN             Europe               52623
# 9                         JPN               Asia               58576
# 10                        HND           Americas                 450
# 11                        SLV           Americas                 450
# 12                        GTM           Americas                 600
# 13                        SLV           Americas                 300
# 14                        NIC           Americas                 400
# 15                        HND           Americas                 300
# 16                        ESP             Europe                1000
# 17                        MAR             Africa                4000
# 18                        ITA             Europe                2850
# 19                        TUR             Europe                6650
# 20                        YUG             Europe               10800
# 21                        TUR             Europe               30000
# 22                        BGR             Europe               19200
# 23                        GRC             Europe                3000
# 24                        YUG             Europe                8165
# 25                        GRC             Europe                1103
# 26                        BGR             Europe                7944
# 27                        ROU             Europe                 662
# 28                        TUR             Europe                8826
# 29                        GRC             Europe                5000
# ..                        ...                ...                 ...
# 165                       CUB           Americas                 700
# 166                       SOM             Africa                3500
# 167                       ETH             Africa                1800
# 168                       UGA             Africa                1650
# 169                       TZA             Africa                1597
# 170                       LBY             Africa                 600
# 171                       CHN               Asia               26000
# 172                       DRV               Asia               19000
# 173                       IRN        Middle East              390200
# 174                       IRQ        Middle East              254300
# 175                       ARG           Americas                 746
# 176                       GBR             Europe                 218
# 177                       SYR        Middle East                 235
# 178                       ISR        Middle East                1000
# 179                       DRV               Asia                1350
# 180                       CHN               Asia                1650
# 181                       IRQ        Middle East               28326
# 182                       OMN        Middle East                   0
# 183                       ARE        Middle East                   6
# 184                       QAT        Middle East                   0
# 185                       KWT        Middle East                 600
# 186                       SAU        Middle East                  29
# 187                       EGY             Africa                  10
# 188                       MAR             Africa                   0
# 189                       ITA             Europe                   0
# 190                       FRA             Europe                   2
# 191                       GBR             Europe                  24
# 9      None          Interstate
# 10     None          Interstate
# 11     None          Interstate
# 12     None          Interstate
# 13     None          Interstate
# 14     None          Interstate
# 15     None          Interstate
# 16     None          Interstate
# 17     None          Interstate
# 18     None          Interstate
# 19     None          Interstate
# 20     None          Interstate
# 21     None          Interstate
# 22     None          Interstate
# 23     None          Interstate
# 24     None          Interstate
# 25     None          Interstate
# 26     None          Interstate
# 27     None          Interstate
# 28     None          Interstate
# 29     None          Interstate
# ..      ...                 ...
# 165    None          Interstate
# 166    None          Interstate
# 167    None          Interstate
# 168    None          Interstate
# 169    None          Interstate
# 170    None          Interstate
# 171    None          Interstate
# 172    None          Interstate
# 173    None          Interstate
# 174    None          Interstate
# 175    None          Interstate
# 176    None          Interstate
# 177    None          Interstate
# 178    None          Interstate
# 179    None          Interstate
# 180    None          Interstate
# 181    None          Interstate
# 182    None          Interstate
# 183    None          Interstate
# 184    None          Interstate
# 185    None          Interstate
# 186    None          Interstate
# 187    None          Interstate
# 188    None          Interstate
# 189    None          Interstate
# 190    None          Interstate
# 191    None          Interstate
# 192    None          Interstate
# 193    None          Interstate
# 194    None          Interstate
#
# [195 rows x 11 columns]

# %%
# Use country_converter_df to join Maddison codes and region to COW dataframe
COW_intrastate_country_df = COW_intrastate_country_df[["statenum","pbdeadbest","yrbeg1","yrend_last","warno"]]
COW_intrastate_country_df.columns = ["participant_country_id","participant_deaths","conflict_start_year","conflict_end_year","COW_id"]
COW_intrastate_country_df = COW_intrastate_country_df.join(country_converter_df,on="participant_country_id")
COW_intrastate_country_df["conflict_name"] = None
COW_intrastate_country_df["UCDP_id"] = None
COW_intrastate_country_df["state_conflict_type"] = "Internal"
COW_intrastate_country_df = COW_intrastate_country_df[country_conflicts_columns] # Keep only relevant columns
COW_intrastate_country_df
# Out:
#           participant_country  participant_country_id  \
# 0                    Colombia                     100
# 1                   Venezuela                     101
# 2                   Venezuela                     101
# 3                      Turkey                     640
# 4                     Uruguay                     165
# 5                        USSR                     364
# 6                     Romania                     360
# 7                      France                     220
# 8                     Morocco                     600
# 9                        Iran                     630
# 10                       USSR                     364
# 11                     Mexico                      70
# 12                    Morocco                     600
# 13                     France                     220
# 14                   Paraguay                     150
# 15                      China                     710
# 16                      China                     710
# 17                      China                     710
# 18                       USSR                     364
# 19                       USSR                     364
# 20                     France                     220
# 21                      Japan                     740
# 22   United States of America                       2
# 23             United Kingdom                     200
# 24                    Finland                     375
# 25                      China                     710
# 26                    Finland                     375
# 27                    Hungary                     310
# 28                       USSR                     364
# 29                     Mexico                      70
# ..                        ...                     ...
# 160                    Rwanda                     517
# 161              Sierra Leone                     451
# 162       Serbia (Yugoslavia)                     342
# 163                    Turkey                     640
# 164                   Burundi                     516
# 165                   Georgia                     372
# 166                   Armenia                     371
# 167                Azerbaijan                     373
# 168        Bosnia-Herzegovina                     346
# 169       Serbia (Yugoslavia)                     342
# 170                Tajikistan                     702
# 171                   Nigeria                     475
# 172                   Liberia                     450
# 173                    Angola                     540
# 174          DR Congo (Zaire)                     490
# 175                   Burundi                     516
# 176                  Cambodia                     811
# 177                      USSR                     364
# 178                    Rwanda                     517
# 179                     Yemen                     679
# 180                  Pakistan                     770
# 181                    Uganda                     500
# 182                   Liberia                     450
# 183                      Iraq                     645
# 184          DR Congo (Zaire)                     490
# 185                    Uganda                     500
# 186                    Rwanda                     517
# 187                    Angola                     540
# 188                    Angola                     540
# 189                     Congo                     484
#
#     participant_maddison_code participant_region  participant_deaths  \
# 0                         COL           Americas             50000.0
# 1                         VEN           Americas              2000.0
# 2                         VEN           Americas              1050.0
# 3                         TUR             Europe              6322.0
# 4                         URY           Americas               880.0
# 5                         SUN             Europe             16500.0
# 6                         ROU             Europe              6500.0
# 7                         FRA             Europe               200.0
# 8                         MAR             Africa              1000.0
# 9                         IRN        Middle East              1000.0
# 10                        SUN             Europe               100.0
# 11                        MEX           Americas            250000.0
# 12                        MAR             Africa              1500.0
# 13                        FRA             Europe               150.0
# 14                        PRY           Americas              2000.0
# 15                        CHN               Asia              1500.0
# 16                        CHN               Asia              7500.0
# 17                        CHN               Asia              5000.0
# 18                        SUN             Europe              3000.0
# 19                        SUN             Europe            822775.0
# 20                        FRA             Europe                50.0
# 21                        JPN               Asia              1500.0
# 22                        USA           Americas               275.0
# 23                        GBR             Europe               350.0
# 24                        FIN             Europe                50.0
# 25                        CHN               Asia              1000.0
# 26                        FIN             Europe             11750.0
# 27                        HUN             Europe              4000.0
# 28                        SUN             Europe              6700.0
# 29                        MEX           Americas              7000.0
# ..                        ...                ...                 ...
# 160                       RWA             Africa              4800.0
# 161                       SLE             Africa              3497.0
# 162                       SRB             Europe              9150.0
# 163                       TUR             Europe             30300.0
# 164                       BDI             Africa               550.0
# 165                       GEO             Europe              2940.0
# 166                       ARM             Europe              4000.0
# 167                       AZE             Europe             16000.0
# 168                       BIH             Europe             55000.0
# 169                       SRB             Europe                 NaN
# 170                       TJK               Asia             41324.0
# 171                       NGA             Africa                 NaN
# 172                       LBR             Africa              2500.0
# 173                       AGO             Africa             43000.0
# 174                       COD             Africa               650.0
# 175                       BDI             Africa              1789.0
# 176                       KHM               Asia               500.0
# 177                       SUN             Europe             45500.0
# 178                       RWA             Africa               700.0
# 179                       YEM        Middle East              5500.0
# 180                       PAK               Asia              1225.0
# 181                       UGA             Africa               750.0
# 182                       LBR             Africa                 NaN
# 183                       IRQ        Middle East              1500.0
# 184                       COD             Africa              4000.0
# 185                       UGA             Africa                 NaN
# 186                       RWA             Africa                 NaN
# 187                       AGO             Africa                 NaN
# 188                       AGO             Africa                 NaN
# 189                       COG             Africa              7000.0
#
#     conflict_name  conflict_start_year  conflict_end_year  COW_id UCDP_id  \
# 0            None                 1899               1903     582    None
# 1            None                 1899               1899     583    None
# 2            None                 1901               1903     584    None
# 3            None                 1903               1903     585    None
# 4            None                 1904               1904     587    None
# 5            None                 1905               1906     588    None
# 6            None                 1907               1907     589    None
# 7            None                 1907               1908     590    None
# 8            None                 1907               1908     590    None
# 9            None                 1908               1909     591    None
# 10           None                 1909               1909     591    None
# 11           None                 1910               1920     592    None
# 12           None                 1911               1911     593    None
# 13           None                 1911               1911     593    None
# 14           None                 1911               1912     594    None
# 15           None                 1911               1911     595    None
# 16           None                 1913               1913     597    None
# 17           None                 1914               1914     598    None
# 18           None                 1916               1917     599    None
# 19           None                 1917               1921     600    None
# 20           None                 1918               1919     600    None
# 21           None                 1918               1920     600    None
# 22           None                 1918               1920     600    None
# 23           None                 1918               1920     600    None
# 24           None                 1919               1919     600    None
# 25           None                 1917               1918     602    None
# 26           None                 1918               1918     603    None
# 27           None                 1919               1920     604    None
# 28           None                 1920               1921     605    None
# 29           None                 1923               1924     607    None
# ..            ...                  ...                ...     ...     ...
# 160          None                 1990               1993     729    None
# 161          None                 1991               1996     730    None
# 162          None                 1991               1992     733    None
# 163          None                 1991               -888     734    None
# 164          None                 1991               1991     735    None
# 165          None                 1991               1994     736    None
# 166          None                 1991               1994     737    None
# 167          None                 1991               1994     737    None
# 168          None                 1992               1995     738    None
# 169          None                 1992               1992     738    None
# 170          None                 1992               1997     740    None
# 171          None                 1992               1992     742    None
# 172          None                 1992               1995     742    None
# 173          None                 1992               1994     743    None
# 174          None                 1993               1993     744    None
# 175          None                 1993               -888     745    None
# 176          None                 1993               1997     747    None
# 177          None                 1994               1996     748    None
# 178          None                 1994               1994     749    None
# 179          None                 1994               1994     750    None
# 180          None                 1994               1995     752    None
# 181          None                 1996               -888     753    None
# 182          None                 1996               1996     754    None
# 183          None                 1996               1996     756    None
# 184          None                 1996               1997     757    None
# 185          None                 1997               1997     757    None
# 186          None                 1997               1997     757    None
# 187          None                 1997               1997     757    None
# 188          None                 1997               1997     760    None
# 189          None                 1997               1997     760    None
#
#     state_conflict_type
# 0              Internal
# 1              Internal
# 2              Internal
# 3              Internal
# 4              Internal
# 5              Internal
# 6              Internal
# 7              Internal
# 8              Internal
# 9              Internal
# 10             Internal
# 11             Internal
# 12             Internal
# 13             Internal
# 14             Internal
# 15             Internal
# 16             Internal
# 17             Internal
# 18             Internal
# 19             Internal
# 20             Internal
# 21             Internal
# 22             Internal
# 23             Internal
# 24             Internal
# 25             Internal
# 26             Internal
# 27             Internal
# 28             Internal
# 29             Internal
# ..                  ...
# 160            Internal
# 161            Internal
# 162            Internal
# 163            Internal
# 164            Internal
# 165            Internal
# 166            Internal
# 167            Internal
# 168            Internal
# 169            Internal
# 170            Internal
# 171            Internal
# 172            Internal
# 173            Internal
# 174            Internal
# 175            Internal
# 176            Internal
# 177            Internal
# 178            Internal
# 179            Internal
# 180            Internal
# 181            Internal
# 182            Internal
# 183            Internal
# 184            Internal
# 185            Internal
# 186            Internal
# 187            Internal
# 188            Internal
# 189            Internal
#
# [190 rows x 11 columns]

# %%
# Use country_converter_df to join Maddison codes and region to COW dataframe
COW_extrastate_country_df = COW_extrastate_country_df[["statenum","pbdeadbest","yrbeg1","yrend_last","warno"]]
COW_extrastate_country_df.columns = ["participant_country_id","participant_deaths","conflict_start_year","conflict_end_year","COW_id"]
COW_extrastate_country_df = COW_extrastate_country_df.join(country_converter_df,on="participant_country_id")
COW_extrastate_country_df["conflict_name"] = None
COW_extrastate_country_df["UCDP_id"] = None
COW_extrastate_country_df["state_conflict_type"] = "Extrasystemic"
COW_extrastate_country_df = COW_extrastate_country_df[country_conflicts_columns] # Keep only relevant columns
COW_extrastate_country_df
# Out:
#          participant_country  participant_country_id  \
# 0   United States of America                       2
# 1                Philippines                     840
# 2             United Kingdom                     200
# 3                    Somalia                     520
# 4             United Kingdom                     200
# 5               South Africa                     560
# 6                    Nigeria                     475
# 7                    Germany                     255
# 8                    Namibia                     565
# 9                    Germany                     255
# 10                  Tanzania                     510
# 11            United Kingdom                     200
# 12              South Africa                     560
# 13                     Spain                     230
# 14                    France                     220
# 15                     China                     710
# 16                    France                     220
# 17                     Spain                     230
# 18                     China                     710
# 19  United States of America                       2
# 20                     Haiti                      41
# 21            United Kingdom                     200
# 22               Afghanistan                     700
# 23                     Syria                     652
# 24            United Kingdom                     200
# 25                      Iraq                     645
# 26                     Italy                     325
# 27                     Libya                     620
# 28                     Spain                     230
# 29                    France                     220
# ..                       ...                     ...
# 41                 Indonesia                     850
# 42                    France                     220
# 43           Vietnam (North)                     816
# 44                    France                     220
# 45                Madagascar                     580
# 46            United Kingdom                     200
# 47                  Malaysia                     820
# 48                     India                     750
# 49                     China                     710
# 50                    France                     220
# 51                   Tunisia                     616
# 52            United Kingdom                     200
# 53                     Kenya                     501
# 54                   Morocco                     600
# 55                    France                     220
# 56                   Algeria                     615
# 57                  Cameroon                     471
# 58                    France                     220
# 59                  Portugal                     235
# 60                    Angola                     540
# 61                  Portugal                     235
# 62                    Guinea                     438
# 63                  Portugal                     235
# 64                Mozambique                     541
# 65                 Indonesia                     850
# 66              South Africa                     560
# 67                   Namibia                     565
# 68                   Morocco                     600
# 69                Mauritania                     435
# 70                   Algeria                     615
#
#    participant_maddison_code participant_region  participant_deaths  \
# 0                        USA           Americas                4234
# 1                        PHL               Asia               16000
# 2                        GBR             Europe                 200
# 3                        SOM             Africa                4000
# 4                        GBR             Europe                5774
# 5                        ZAF             Africa                6650
# 6                        NGA             Africa                 365
# 7                        DEU             Europe                 887
# 8                        NAM             Africa               11000
# 9                        DEU             Europe                 130
# 10                       TZA             Africa                 870
# 11                       GBR             Europe                  56
# 12                       ZAF             Africa                2300
# 13                       ESP             Europe                1623
# 14                       FRA             Europe                1623
# 15                       CHN               Asia                2000
# 16                       FRA             Europe                1000
# 17                       ESP             Europe                1000
# 18                       CHN               Asia                1000
# 19                       USA           Americas                  98
# 20                       HTI           Americas                2250
# 21                       GBR             Europe                 236
# 22                       AFG        Middle East                1000
# 23                       SYR        Middle East                5000
# 24                       GBR             Europe                 426
# 25                       IRQ        Middle East                8450
# 26                       ITA             Europe                5000
# 27                       LBY             Africa               35000
# 28                       ESP             Europe               17020
# 66          None                 1975               1988     440    None
# 67          None                 1975               1988     440    None
# 68          None                 1975               1983     441    None
# 69          None                 1975               1979     441    None
# 70          None                 1975               1979     441    None
#
#    state_conflict_type
# 0        Extrasystemic
# 1        Extrasystemic
# 2        Extrasystemic
# 3        Extrasystemic
# 4        Extrasystemic
# 5        Extrasystemic
# 6        Extrasystemic
# 7        Extrasystemic
# 8        Extrasystemic
# 9        Extrasystemic
# 10       Extrasystemic
# 11       Extrasystemic
# 12       Extrasystemic
# 13       Extrasystemic
# 14       Extrasystemic
# 15       Extrasystemic
# 16       Extrasystemic
# 17       Extrasystemic
# 18       Extrasystemic
# 19       Extrasystemic
# 20       Extrasystemic
# 21       Extrasystemic
# 22       Extrasystemic
# 23       Extrasystemic
# 24       Extrasystemic
# 25       Extrasystemic
# 26       Extrasystemic
# 27       Extrasystemic
# 28       Extrasystemic
# 29       Extrasystemic
# ..                 ...
# 41       Extrasystemic
# 42       Extrasystemic
# 43       Extrasystemic
# 44       Extrasystemic
# 45       Extrasystemic
# 46       Extrasystemic
# 47       Extrasystemic
# 48       Extrasystemic
# 49       Extrasystemic
# 50       Extrasystemic
# 51       Extrasystemic
# 52       Extrasystemic
# 53       Extrasystemic
# 54       Extrasystemic
# 55       Extrasystemic
# 56       Extrasystemic
# 57       Extrasystemic
# 58       Extrasystemic
# 59       Extrasystemic
# 60       Extrasystemic
# 61       Extrasystemic
# 62       Extrasystemic
# 63       Extrasystemic
# 64       Extrasystemic
# 65       Extrasystemic
# 66       Extrasystemic
# 67       Extrasystemic
# 68       Extrasystemic
# 69       Extrasystemic
# 70       Extrasystemic
#
# [71 rows x 11 columns]

# %%
# Concatenate COW dataframes together
COW_country_conflicts_df = pd.concat([COW_interstate_country_df,COW_intrastate_country_df,COW_extrastate_country_df])

# %%
# Create dictionary that uses conflict_years_df to work out the share of a conflict's deaths that occurred in each year
COW_conflict_dict = {}
for i in list(conflict_years_df["COW_id"].unique()):
    if i >= 0:
        COW_conflict_dict[i] = {}
        conflict_year_rows = conflict_years_df[conflict_years_df["COW_id"]==i] # All rows in conflict_years_df for this conflict
        COW_conflict_dict[i]["conflict_name"] = conflict_year_rows.iloc[0]["conflict_name"]
        COW_conflict_dict[i]["state_conflict_type"] = conflict_year_rows.iloc[0]["state_conflict_type"]
        COW_conflict_dict[i]["years"] = {}
        
        # Create a separate entry in each conflict's dictionary for each year in that conflict
        for y in list(conflict_year_rows["year"].unique()):
            COW_conflict_dict[i]["years"][y] = {"deaths":0,"deaths_share":0}
            COW_conflict_dict[i]["years"][y]["deaths"] = np.sum(conflict_year_rows[conflict_year_rows["year"]==y]["best_deaths"])
            COW_conflict_dict[i]["years"][y]["deaths_share"] = COW_conflict_dict[i]["years"][y]["deaths"] / np.sum(conflict_year_rows["best_deaths"])

# %%
# Create a list of lists, which for each conflict adds a row for each country in each year, with the relevant death toll 
COW_country_conflict_year_lists = []

# Loop through rows of each country for each conflict
for i,r in COW_country_conflicts_df.iterrows():
    row_list = list(r) # Each of these rows is a country for each conflict
    country_conflict_start_year = r["conflict_start_year"]
    country_conflict_end_year = r["conflict_end_year"]
    deaths_share_without_country_fighting = 0 # Used to discount deaths before a country enters a war or after it exits
    
    if r["COW_id"] in COW_conflict_dict:
        
        # Loop through each conflict in COW_conflict_dict, checking what share of deaths occurred when a country was not fighting
        for k,v in COW_conflict_dict[r["COW_id"]]["years"].items():
            if k < country_conflict_start_year:
                deaths_share_without_country_fighting += v["deaths_share"]
            elif k > country_conflict_end_year:
                deaths_share_without_country_fighting += v["deaths_share"]
                
        # Loop through each conflict in COW_conflict_dict, allocating each country's deaths by year       
        for k,v in COW_conflict_dict[r["COW_id"]]["years"].items():
            if k < country_conflict_start_year:
                pass
            elif k > country_conflict_end_year:
                pass
            else:
                try:
                    # Calculate what share of country's deaths happened in each year, and allocate those deaths by year
                    country_year_deaths = (v["deaths_share"]/(1-deaths_share_without_country_fighting))*r["participant_deaths"]
                except Exception:
                    country_year_deaths = 0
                    
                # Append the conflict name, the year, the country's annual share of deaths and its annual death toll
                year_row_list = [] + row_list
                year_row_list[5] = COW_conflict_dict[r["COW_id"]]["conflict_name"]
                year_row_list.append(k) # The relevant year
                try:
                    year_row_list.append((v["deaths_share"]/(1-deaths_share_without_country_fighting)))
                except Exception:
                    year_row_list.append(0)
                year_row_list.append(country_year_deaths)
                COW_country_conflict_year_lists.append(year_row_list)

# %%
# Turn the list of lists into a dataframe, where each row is a country's annual death toll in a conflict
COW_country_conflict_years_df = pd.DataFrame(COW_country_conflict_year_lists,columns=country_conflict_year_columns)

# %%
COW_country_conflict_years_df
# Out:
#            participant_country  participant_country_id  \
# 0                        China                     710
# 1                         USSR                     364
# 2                        Japan                     740
# 3               United Kingdom                     200
# 4     United States of America                       2
# 5                       France                     220
# 6                         USSR                     364
# 7                        China                     710
# 8                         USSR                     364
# 9                         USSR                     364
# 10                       Japan                     740
# 11                       Japan                     740
# 12                    Honduras                      91
# 13                 El Salvador                      92
# 14                   Guatemala                      90
# 15                 El Salvador                      92
# 16                   Nicaragua                      93
# 17                    Honduras                      91
# 18                       Spain                     230
# 19                       Spain                     230
# 20                     Morocco                     600
# 21                     Morocco                     600
# 22                       Italy                     325
# 23                       Italy                     325
# 24                      Turkey                     640
# 25                      Turkey                     640
# 26                  Yugoslavia                     345
# 27                  Yugoslavia                     345
# 28                      Turkey                     640
# 29                      Turkey                     640
# ...                        ...                     ...
# 1444                   Namibia                     565
# 1445                   Namibia                     565
# 1446                   Namibia                     565
# 1447                   Namibia                     565
# 1448                   Namibia                     565
# 1449                   Namibia                     565
# 1450                   Namibia                     565
# 1451                   Namibia                     565
# 1452                   Namibia                     565
# 1453                   Namibia                     565
# 1454                   Namibia                     565
# 1455                   Morocco                     600
# 1456                   Morocco                     600
# 1457                   Morocco                     600
# 1458                   Morocco                     600
# 1459                   Morocco                     600
# 1460                   Morocco                     600
# 1461                   Morocco                     600
# 1462                   Morocco                     600
# 1463                   Morocco                     600
# 1464                Mauritania                     435
# 1465                Mauritania                     435
# 1466                Mauritania                     435
# 1467                Mauritania                     435
# 1468                Mauritania                     435
# 1469                   Algeria                     615
# 1470                   Algeria                     615
# 1471                   Algeria                     615
# 1472                   Algeria                     615
# 1473                   Algeria                     615
#
#      participant_maddison_code participant_region  participant_deaths  \
# 0                          CHN               Asia              2000.0
# 1                          SUN             Europe               302.0
# 2                          JPN               Asia               622.0
# 3                          GBR             Europe                34.0
# 4                          USA           Americas                21.0
# 5                          FRA             Europe                24.0
# 6                          SUN             Europe               242.0
# 7                          CHN               Asia              3758.0
# 8                          SUN             Europe             52623.0
# 9                          SUN             Europe             52623.0
# 10                         JPN               Asia             58576.0
# 11                         JPN               Asia             58576.0
# 12                         HND           Americas               450.0
# 13                         SLV           Americas               450.0
# 14                         GTM           Americas               600.0
# 15                         SLV           Americas               300.0
# 16                         NIC           Americas               400.0
# 17                         HND           Americas               300.0
# 18                         ESP             Europe              1000.0
# 19                         ESP             Europe              1000.0
# 20                         MAR             Africa              4000.0
# 21                         MAR             Africa              4000.0
# 22                         ITA             Europe              2850.0
# 23                         ITA             Europe              2850.0
# 24                         TUR             Europe              6650.0
# 25                         TUR             Europe              6650.0
# 26                         YUG             Europe             10800.0
# 27                         YUG             Europe             10800.0
# 28                         TUR             Europe             30000.0
# 29                         TUR             Europe             30000.0
# ...                        ...                ...                 ...
# 1444                       NAM             Africa             24200.0
# 1445                       NAM             Africa             24200.0
# 1446                       NAM             Africa             24200.0
# 1447                       NAM             Africa             24200.0
# 1448                       NAM             Africa             24200.0
# 1449                       NAM             Africa             24200.0
# 1450                       NAM             Africa             24200.0
# 1451                       NAM             Africa             24200.0
# 1452                       NAM             Africa             24200.0
# 1453                       NAM             Africa             24200.0
# 1454                       NAM             Africa             24200.0
# 1455                       MAR             Africa             10600.0
# 1456                       MAR             Africa             10600.0
# 1457                       MAR             Africa             10600.0
# 1458                       MAR             Africa             10600.0
# 1459                       MAR             Africa             10600.0
# 1460                       MAR             Africa             10600.0
# 1461                       MAR             Africa             10600.0
# 1462                       MAR             Africa             10600.0
# 1463                       MAR             Africa             10600.0
# 1464                       MRT             Africa              2000.0
# 1465                       MRT             Africa              2000.0
# 1466                       MRT             Africa              2000.0
# 1467                       MRT             Africa              2000.0
# 1468                       MRT             Africa              2000.0
# 1469                       DZA             Africa               400.0
# 1470                       DZA             Africa               400.0
# 1471                       DZA             Africa               400.0
# 1472                       DZA             Africa               400.0
# 1473                       DZA             Africa               400.0
#
#                 conflict_name  conflict_start_year  conflict_end_year  COW_id  \
# 0             Boxer Rebellion                 1900               1900      82
# 1             Boxer Rebellion                 1900               1900      82
# 2             Boxer Rebellion                 1900               1900      82
# 3             Boxer Rebellion                 1900               1900      82
# 4             Boxer Rebellion                 1900               1900      82
# 5             Boxer Rebellion                 1900               1900      82
# 6                Sino-Russian                 1900               1900      83
# 7                Sino-Russian                 1900               1900      83
# 15      None          Interstate  1907           1.000000    300.000000
# 16      None          Interstate  1907           1.000000    400.000000
# 17      None          Interstate  1907           1.000000    300.000000
# 18      None          Interstate  1909           0.500000    500.000000
# 19      None          Interstate  1910           0.500000    500.000000
# 20      None          Interstate  1909           0.500000   2000.000000
# 21      None          Interstate  1910           0.500000   2000.000000
# 22      None          Interstate  1911           0.500000   1425.000000
# 23      None          Interstate  1912           0.500000   1425.000000
# 24      None          Interstate  1911           0.500000   3325.000000
# 25      None          Interstate  1912           0.500000   3325.000000
# 26      None          Interstate  1912           0.500000   5400.000000
# 27      None          Interstate  1913           0.500000   5400.000000
# 28      None          Interstate  1912           0.500000  15000.000000
# 29      None          Interstate  1913           0.500000  15000.000000
# ...      ...                 ...   ...                ...           ...
# 1444    None       Extrasystemic  1978           0.058000   1403.600000
# 1445    None       Extrasystemic  1979           0.120000   2904.000000
# 1446    None       Extrasystemic  1980           0.200000   4840.000000
# 1447    None       Extrasystemic  1981           0.200000   4840.000000
# 1448    None       Extrasystemic  1982           0.100000   2420.000000
# 1449    None       Extrasystemic  1983           0.100000   2420.000000
# 1450    None       Extrasystemic  1984           0.038000    919.600000
# 1451    None       Extrasystemic  1985           0.038000    919.600000
# 1452    None       Extrasystemic  1986           0.040000    968.000000
# 1453    None       Extrasystemic  1987           0.040000    968.000000
# 1454    None       Extrasystemic  1988           0.040000    968.000000
# 1455    None       Extrasystemic  1975           0.111077   1177.415385
# 1456    None       Extrasystemic  1976           0.111077   1177.415385
# 1457    None       Extrasystemic  1977           0.111077   1177.415385
# 1458    None       Extrasystemic  1978           0.111077   1177.415385
# 1459    None       Extrasystemic  1979           0.111077   1177.415385
# 1460    None       Extrasystemic  1980           0.111154   1178.230769
# 1461    None       Extrasystemic  1981           0.111154   1178.230769
# 1462    None       Extrasystemic  1982           0.111154   1178.230769
# 1463    None       Extrasystemic  1983           0.111154   1178.230769
# 1464    None       Extrasystemic  1975           0.200000    400.000000
# 1465    None       Extrasystemic  1976           0.200000    400.000000
# 1466    None       Extrasystemic  1977           0.200000    400.000000
# 1467    None       Extrasystemic  1978           0.200000    400.000000
# 1468    None       Extrasystemic  1979           0.200000    400.000000
# 1469    None       Extrasystemic  1975           0.200000     80.000000
# 1470    None       Extrasystemic  1976           0.200000     80.000000
# 1471    None       Extrasystemic  1977           0.200000     80.000000
# 1472    None       Extrasystemic  1978           0.200000     80.000000
# 1473    None       Extrasystemic  1979           0.200000     80.000000
#
# [1474 rows x 14 columns]

# %% [markdown]
# ## Step 3: clean UCDP data ##

# %%
# Filter the UCDP dataframe to include only state-based conflict
UCDP_state_conflict_df = UCDP_all_df[UCDP_all_df["type_of_violence"]==1]

# Create a list of all the dyad pairing in the UCDP dataframe
UCDP_dyad_list = list(UCDP_state_conflict_df["dyad_new_id"].unique())

# %%
UCDP_state_conflict_df
# Out:
#             id  year  active_year  type_of_violence  conflict_new_id  \
# 0         7578  1989            1                 1              309
# 3        13930  1989            1                 1              332
# 142861                Government of Afghanistan - Taleban            130
# 142862                Government of Afghanistan - Taleban            130
# 142863                     Government of Afghanistan - IS            130
# 142867                           Government of Egypt - IS            117
# 142868                         Government of Turkey - PKK            115
# 142869                         Government of Uganda - ADF             90
# 142873         Government of Egypt - Harakit Sawa'id Misr            117
# 142875                         Government of Nigeria - IS             84
# 142876  Government of DR Congo (Zaire) - CNPSC (Yakutu...             89
# 142877                Government of Afghanistan - Taleban            130
# 142878                     Government of Afghanistan - IS            130
# 142879   Government of South Sudan - SPLM/A In Opposition            113
# 142881                         Government of Turkey - PKK            115
# 142882                         Government of Turkey - PKK            115
# 142883                 Government of Somalia - Al-Shabaab             95
# 142884                 Government of Somalia - Al-Shabaab             95
# 142885                   Government of Kenya - Al-Shabaab             91
# 142889           Government of India - Kashmir insurgents            141
# 142890       Government of India - Government of Pakistan            141
# 142891                   Government of India - CPI-Maoist            141
# 142893                     Government of Afghanistan - IS            130
# 142894                Government of Afghanistan - Taleban            130
# 142895                Government of Afghanistan - Taleban            130
# 142898                Government of Afghanistan - Taleban            130
# 142901                Government of Afghanistan - Taleban            130
#
#        gwnoa  ...  date_prec  date_start    date_end deaths_a  deaths_b  \
# 0        625  ...          5  01/01/1989  03/10/1989     2700         0
# 3        541  ...          4  01/01/1989  31/01/1989        0        60
# 19       910  ...          5  01/01/1989  29/11/1989        6         0
# 20       530  ...          5  01/01/1989  31/12/1989        0         0
# 21       750  ...          5  01/01/1989  31/12/1989        0         0
# 22       775  ...          5  01/01/1989  31/12/1989        0         0
# 28       750  ...          5  01/01/1989  31/12/1989        8         0
# 29       750  ...          5  01/01/1989  31/12/1989      172       633
# 30       750  ...          1  01/01/1989  01/01/1989        2         3
# 31       811  ...          5  01/01/1989  31/05/1989        0        54
# 32       811  ...          5  01/01/1989  31/05/1989        0        53
# 33       811  ...          5  01/01/1989  30/09/1989      100         0
# 34       750  ...          5  01/01/1989  16/03/1989       35         0
# 35        92  ...          4  01/01/1989  31/01/1989        0       116
# 36        92  ...          5  01/01/1989  29/04/1989      165       275
# 37        92  ...          5  01/01/1989  31/12/1989      326      1216
# 38       840  ...          5  01/01/1989  03/07/1989       42         0
# 39       700  ...          1  01/01/1989  01/01/1989        0         4
# 40       700  ...          1  01/01/1989  01/01/1989        0         4
# 41        93  ...          5  01/01/1989  31/12/1989        0        74
# 42       640  ...          5  01/01/1989  15/08/1989       16         0
# 43       645  ...          5  01/01/1989  31/12/1989        0         0
# 44       645  ...          5  01/01/1989  31/12/1989        0         0
# 45       135  ...          5  01/01/1989  26/10/1989        0       552
# 46       135  ...          4  01/01/1989  15/01/1989       11         0
# 47       660  ...          5  01/01/1989  22/09/1989        0         0
# 48       700  ...          5  01/01/1989  31/12/1989        0         0
# 58        90  ...          5  01/01/1989  31/12/1989        0         3
# 59        90  ...          5  01/01/1989  31/12/1989        0         1
# 60        90  ...          5  01/01/1989  31/12/1989        0         1
# ...      ...  ...        ...         ...         ...      ...       ...
# 142863                0              0     4     4     4
# 142867                7              3    12    12    12
# 142868                0              0     4     4     4
# 142869                0              0     2     2     2
# 142873                0              0     3     3     3
# 142875                0              0     8     8    12
# 142876                0              3     3     3     3
# 142877                0              0    10    10    10
# 142878                0              0     5     5     5
# 142879                0              0     0     0     1
# 142881                0              0     2     2     2
# 142882                0              0    11    11    11
# 142883                0              1     2     2     2
# 142884                0              1     1     1     1
# 142885                0              0     5     5     5
# 142889                0              0     8     8     8
# 142890                0              0     1     1     1
# 142891                0              0     1     1     1
# 142893                0              0     5     5     5
# 142894                0              0    11    11    10
# 142895                0              0     5     5     6
# 142898                0              0    10    10    11
# 142901                0              0     9     9     9
#
# [100626 rows x 42 columns]

# %%
# Create a dataframe of each country's deaths in each dyad pairing in each year
# Create a list of lists, where each list is a row
dyad_years_list = []

for d in tqdm_notebook(UCDP_dyad_list):
    dyad_incidents_df = UCDP_state_conflict_df[UCDP_state_conflict_df["dyad_new_id"]==d] # All the incidents in each dyad
    side_a_name = dyad_incidents_df.iloc[0]["side_a"]
    side_b_name = dyad_incidents_df.iloc[0]["side_b"]
    side_a_gwn_id = dyad_incidents_df.iloc[0]["gwnoa"]
    side_b_gwn_id = dyad_incidents_df.iloc[0]["gwnob"]
    
    # Because some of the gwn_ids are strings, each one needs to be converted to a float
    try:
        side_a_gwn_id = float(side_a_gwn_id)
    except Exception:
        pass

    try:
        side_b_gwn_id = float(side_b_gwn_id)
    except Exception:
        pass
    
    # For each participant, the country Maddison codes and regions need to assigned from country_converter_df
    side_a_participant_country = None
    side_b_participant_country = None
    side_a_participant_country_id = None
    side_b_participant_country_id = None
    side_a_participant_maddison_code = None
    side_b_participant_maddison_code = None
    side_a_participant_region = None
    side_b_participant_region = None
    
    # If gwn_id is a number less than 1000, it refers to a state; participants that are not states will be dealt with later
    try:    
        if side_a_gwn_id < 1000:
            side_a_participant_country_id = side_a_gwn_id
            side_a_participant_country = country_converter_df.loc[side_a_gwn_id]["participant_country"]
            side_a_participant_region = country_converter_df.loc[side_a_gwn_id]["participant_region"]
            side_a_participant_maddison_code = country_converter_df.loc[side_a_gwn_id]["participant_maddison_code"]
        if side_b_gwn_id < 1000:
            side_b_participant_country_id = side_b_gwn_id
            side_b_participant_country = country_converter_df.loc[side_b_gwn_id]["participant_country"]
            side_b_participant_region = country_converter_df.loc[side_b_gwn_id]["participant_region"]
            side_b_participant_maddison_code = country_converter_df.loc[side_b_gwn_id]["participant_maddison_code"]
            
    except Exception: # for dyad 883, which attributes 2003 Iraq invasion deaths to USA, UK and Australia with a string gwn_id
            side_a_participant_country_id = 2
            side_a_participant_country = "United States of America"
            side_a_participant_region = "Americas"
            side_a_participant_maddison_code = "USA"
    
    # To identify the nationalities of non-state armies, calculate where most deaths in a dyad pair occurred
    # This dictionary includes the death toll in all countries in which the dyad pair fought
    dyad_location_deaths = {}
    for i,r in dyad_incidents_df.iterrows():
        if r["country_id"] in dyad_location_deaths:
            dyad_location_deaths[r["country_id"]] += r["best"] # Add the best estimate of deaths to the toll for that country
        else:
            dyad_location_deaths[r["country_id"]] = r["best"]
            
    # For participants that do not have a country_id, use the country in which the death toll is highest
    if side_b_participant_country_id is None:
        max_dyad_location = None
        max_dyad_location_deaths = 0
        
        # Find the country with the highest death toll
        for k,v in dyad_location_deaths.items():
            if v > max_dyad_location_deaths:
                max_dyad_location_deaths = v
                max_dyad_location = k
        side_b_participant_country_id = max_dyad_location
        
        # Use country_converter_df to assign the country Maddison codes and regions
        side_b_participant_country = country_converter_df.loc[max_dyad_location]["participant_country"]
        side_b_participant_region = country_converter_df.loc[max_dyad_location]["participant_region"]
        side_b_participant_maddison_code = country_converter_df.loc[max_dyad_location]["participant_maddison_code"]
        
    # Assign a conflict name, start and end years, and a UCDP conflict_id
    conflict_name = side_a_name + " vs. " + side_b_name
    conflict_start_year = np.min(dyad_incidents_df["year"])
    conflict_end_year = np.max(dyad_incidents_df["year"])
    COW_id = None
    UCDP_id = dyad_incidents_df.iloc[0]["conflict_new_id"]
    state_conflict_type = None # This will be assigned later, using 
    
    # Calculate the annual total of deaths for each country in a dyad pair
    for year in range(1989,2018):
        
        year_dyad_incidents_df = dyad_incidents_df[dyad_incidents_df["year"]==year]
        
        if year_dyad_incidents_df.shape[0] > 0: # Filter out years in which no dyadic incident occurred
    
            year_side_a_deaths = 0
            year_side_b_deaths = 0

            for i,r in year_dyad_incidents_df.iterrows():
                year_side_a_deaths = year_side_a_deaths + int(r["deaths_a"])
                year_side_b_deaths = year_side_b_deaths + int(r["deaths_b"])
                
                # Assign deaths of civilians and unknown people to the country in which the incident occurred
                if int(r["country_id"]) == side_a_participant_country_id:
                    year_side_a_deaths = year_side_a_deaths + int(r["deaths_civilians"]) + int(r["deaths_unknown"])
                else:
                    year_side_b_deaths = year_side_b_deaths + int(r["deaths_civilians"]) + int(r["deaths_unknown"])


            year_side_a_list = [side_a_participant_country,side_a_participant_country_id,side_a_participant_maddison_code,side_a_participant_region,
                          year_side_a_deaths,conflict_name,conflict_start_year,conflict_end_year,COW_id,UCDP_id,None,year]

            year_side_b_list = [side_b_participant_country,side_b_participant_country_id,side_b_participant_maddison_code,side_b_participant_region,
                          year_side_b_deaths,conflict_name,conflict_start_year,conflict_end_year,COW_id,UCDP_id,None,year]

            # Append both dyadic lists to the list of lists
            dyad_years_list.append(year_side_a_list)
            dyad_years_list.append(year_side_b_list)
    
UCDP_dyad_years_df = pd.DataFrame(dyad_years_list,columns=country_conflict_year_columns[0:-2])

# %%
# Create a dataframe of each country's deaths in each conflict in each year, using the dyad pairs
UCDP_country_conflict_year_lists = []

# Loop through all UCDP conflict_ids
for i in list(UCDP_dyad_years_df["UCDP_id"].unique()):
    UCDP_conflict_rows = UCDP_dyad_years_df[UCDP_dyad_years_df["UCDP_id"]==i] # Select all dyadic rows with this conflict_id
    UCDP_conflict_countries = list(UCDP_conflict_rows["participant_maddison_code"].unique()) # Select all countries in conflict
    
    # Loop through all countries in the conflict
    for c in UCDP_conflict_countries:
        UCDP_country_conflict_rows = UCDP_conflict_rows[UCDP_conflict_rows["participant_maddison_code"]==c] # Select country's rows
        UCDP_country_conflict_total_deaths = np.sum(UCDP_country_conflict_rows["participant_deaths"]) # Calculate country's total deaths in conflict
        if UCDP_country_conflict_total_deaths > 0:
            
            # For each year between 1989 and 2017, append relevant years for each country in each conflict to the list of lists
            for year in range(1989,2018):
                try:
                    
                    # Calculate the share of a country's total deaths that happened in this year
                    UCDP_country_conflict_year_rows = UCDP_country_conflict_rows[UCDP_country_conflict_rows["year"]==year]
                    UCDP_country_conflict_year_deaths = np.sum(UCDP_country_conflict_year_rows["participant_deaths"])
                    UCDP_country_conflict_year_deaths_share = UCDP_country_conflict_year_deaths / UCDP_country_conflict_total_deaths
                    UCDP_country_conflict_year_row_list = list(UCDP_country_conflict_year_rows.iloc[0])
                    UCDP_country_conflict_year_row_list[4] = UCDP_country_conflict_total_deaths # Fill the "participant deaths" field
                    UCDP_country_conflict_year_row_list.append(UCDP_country_conflict_year_deaths_share)
                    UCDP_country_conflict_year_row_list.append(UCDP_country_conflict_year_deaths)
                    UCDP_country_conflict_year_lists.append(UCDP_country_conflict_year_row_list)
                except Exception:
                    pass
UCDP_country_conflict_years_df = pd.DataFrame(UCDP_country_conflict_year_lists,columns=country_conflict_year_columns)

# %%
# Create a dictionary that contains the conflict_name and conflict_type for every UCDP conflict_id
UCDP_conflict_dict = {}
for i in list(conflict_years_df["UCDP_id"].unique()):
    if i >= 0:
        UCDP_conflict_dict[i] = {}
        conflict_year_rows = conflict_years_df[conflict_years_df["UCDP_id"]==i] # Select relevant rows in conflict_years_df
        UCDP_conflict_dict[i]["conflict_name"] = conflict_year_rows.iloc[0]["conflict_name"]
        UCDP_conflict_dict[i]["state_conflict_type"] = conflict_year_rows.iloc[0]["state_conflict_type"]

# %%
# Add columns to UCDP_country_conflict_years_df that contain the conflict_name and conflict_type
UCDP_country_conflict_years_conflict_name_list = []
UCDP_country_conflict_years_state_conflict_type_list = []

# Loop through rows in UCDP_country_conflict_years_df and look up conflict_name and conflict_type from UCDP_conflict_dict
for i,r in UCDP_country_conflict_years_df.iterrows():
    row_list = list(r)
    row_conflict_name = UCDP_conflict_dict[row_list[9]]["conflict_name"]
    row_state_conflict_type = UCDP_conflict_dict[row_list[9]]["state_conflict_type"]
    UCDP_country_conflict_years_conflict_name_list.append(row_conflict_name)
    UCDP_country_conflict_years_state_conflict_type_list.append(row_state_conflict_type)
UCDP_country_conflict_years_df["conflict_name"] = UCDP_country_conflict_years_conflict_name_list
UCDP_country_conflict_years_df["state_conflict_type"] = UCDP_country_conflict_years_state_conflict_type_list

# %%
UCDP_country_conflict_years_df
# Out:
#      participant_country  participant_country_id participant_maddison_code  \
# 0                  Sudan                   625.0                       SDN
# 1                  Sudan                   625.0                       SDN
# 2                  Sudan                   625.0                       SDN
# 3                  Sudan                   625.0                       SDN
# 4                  Sudan                   625.0                       SDN
# 5                  Sudan                   625.0                       SDN
# 6                  Sudan                   625.0                       SDN
# 7                  Sudan                   625.0                       SDN
# 8                  Sudan                   625.0                       SDN
# 9                  Sudan                   625.0                       SDN
# 10                 Sudan                   625.0                       SDN
# 11                 Sudan                   625.0                       SDN
# 12                 Sudan                   625.0                       SDN
# 13                 Sudan                   625.0                       SDN
# 14                 Sudan                   625.0                       SDN
# 15                 Sudan                   625.0                       SDN
# 16                 Sudan                   625.0                       SDN
# 17                 Sudan                   625.0                       SDN
# 18                 Sudan                   625.0                       SDN
# 19                 Sudan                   625.0                       SDN
# 20                 Sudan                   625.0                       SDN
# 21                 Sudan                   625.0                       SDN
# 22                 Sudan                   625.0                       SDN
# 23                 Sudan                   625.0                       SDN
# 24                 Sudan                   625.0                       SDN
# 25                 Sudan                   625.0                       SDN
# 26                 Sudan                   625.0                       SDN
# 27                 Sudan                   625.0                       SDN
# 28                 Sudan                   625.0                       SDN
# 29            Mozambique                   541.0                       MOZ
# ...                  ...                     ...                       ...
# 1657            Cameroon                   471.0                       CMR
# 1658            Cameroon                   471.0                       CMR
# 1659            Cameroon                   471.0                       CMR
# 1660       Yemen (North)                   678.0                       YAR
# 1661               Niger                   436.0                       NER
# 1662               Niger                   436.0                       NER
# 1663               Niger                   436.0                       NER
# 1664               India                   750.0                       IND
# 1665               India                   750.0                       IND
# 1666               India                   750.0                       IND
# 1667                Chad                   483.0                       TCD
# 1668                Chad                   483.0                       TCD
# 1669                Chad                   483.0                       TCD
# 1670              Russia                   365.0                       RUS
# 1671              Russia                   365.0                       RUS
# 1672              Russia                   365.0                       RUS
# 1673              Turkey                   640.0                       TUR
# 1674              Turkey                   640.0                       TUR
# 1675              Turkey                   640.0                       TUR
# 1676          Bangladesh                   771.0                       BGD
# 1677          Bangladesh                   771.0                       BGD
# 1678          Bangladesh                   771.0                       BGD
# 1679            Pakistan                   770.0                       PAK
# 1680            Pakistan                   770.0                       PAK
# 1681              Jordan                   663.0                       JOR
# 1682         Philippines                   840.0                       PHL
# 1683         Philippines                   840.0                       PHL
# 1684                Iran                   630.0                       IRN
# 1685                Iran                   630.0                       IRN
# 1686                Mali                   432.0                       MLI
#
#      participant_region  participant_deaths  \
# 0                Africa               49070
# 1                Africa               49070
# 2                Africa               49070
# 3                Africa               49070
# 4                Africa               49070
# 5                Africa               49070
# 6                Africa               49070
# 7                Africa               49070
# 8                Africa               49070
# 9                Africa               49070
# 10               Africa               49070
# 11               Africa               49070
# 12               Africa               49070
# 13               Africa               49070
# 14               Africa               49070
# 15               Africa               49070
# 16               Africa               49070
# 17               Africa               49070
# 18               Africa               49070
# 19               Africa               49070
# 20               Africa               49070
# 21               Africa               49070
# 22               Africa               49070
# 23               Africa               49070
# 24               Africa               49070
# 25               Africa               49070
# 26               Africa               49070
# 27               Africa               49070
# 28               Africa               49070
# 29               Africa                4450
# ...                 ...                 ...
# 1657             Africa                 495
# 1658             Africa                 495
# 1659             Africa                 495
# 1681               2016   None    13886                    Internal  2016
# 1682               2017   None    14275                    Internal  2016
# 1683               2017   None    14275                    Internal  2017
# 1684               2017   None    14268                    Internal  2016
# 1685               2017   None    14268                    Internal  2017
# 1686               2017   None    14113  Internationalised internal  2017
#
#       year_deaths_share  year_deaths
# 0              0.086672         4253
# 1              0.088343         4335
# 2              0.026839         1317
# 3              0.022071         1083
# 4              0.019197          942
# 5              0.006868          337
# 6              0.020379         1000
# 7              0.046648         2289
# 8              0.075586         3709
# 9              0.099674         4891
# 10             0.028694         1408
# 11             0.057897         2841
# 12             0.069452         3408
# 13             0.041186         2021
# 14             0.040738         1999
# 15             0.066803         3278
# 16             0.003281          161
# 17             0.020420         1002
# 18             0.004871          239
# 19             0.012187          598
# 20             0.007194          353
# 21             0.020624         1012
# 22             0.025657         1259
# 23             0.023905         1173
# 24             0.012146          596
# 25             0.017444          856
# 26             0.025759         1264
# 27             0.026778         1314
# 28             0.002690          132
# 29             0.258202         1149
# ...                 ...          ...
# 1657           0.571717          283
# 1658           0.381818          189
# 1659           0.046465           23
# 1660           1.000000          246
# 1661           0.263889          171
# 1662           0.422840          274
# 1663           0.313272          203
# 1664           0.651822          161
# 1665           0.190283           47
# 1666           0.157895           39
# 1667           0.783862          272
# 1668           0.051873           18
# 1669           0.164265           57
# 1670           0.310734           55
# 1671           0.389831           69
# 1672           0.299435           53
# 1673           0.131148           16
# 1674           0.803279           98
# 1675           0.065574            8
# 1676           0.011236            1
# 1677           0.460674           41
# 1678           0.528090           47
# 1679           0.459459           68
# 1680           0.540541           80
# 1681           1.000000           34
# 1682           0.102108          155
# 1683           0.897892         1363
# 1684           0.341463           14
# 1685           0.658537           27
# 1686           1.000000           43
#
# [1687 rows x 14 columns]

# %% [markdown]
# ## Step 4: combine both dataframes, and patch in Iraq, Afghanistan and Syria ##

# %%
# Concatenate COW and UCDP dataframes, excluding COW data from 1989 onwards
country_conflict_years_df = pd.concat([COW_country_conflict_years_df[COW_country_conflict_years_df["year"]<=1988],UCDP_country_conflict_years_df])

# %%
# Patch in iran_and_afghanistan_df, which contains data for those wars from iCasualties.org 
iraq_and_afghanistan_df = pd.read_csv("source_data/icasualties_conflict_data/icasualties_conflict_deaths_in_iraq_and_afghanistan.csv")

# Filter out all American rows from 2000 onwards, which are actually for the coalition
country_conflict_years_df = country_conflict_years_df[~((country_conflict_years_df["participant_maddison_code"]=="USA")&(country_conflict_years_df["year"]>2000))]

# Concatenate the dataframes together
country_conflict_years_df = pd.concat([country_conflict_years_df,iraq_and_afghanistan_df])

# %%
# Patch in syria_df, which includes deaths that are not contained in the UCDP incident data
syria_df = pd.read_csv("source_data/UCDP_conflict_data/UCDP_18.1_conflict_deaths_in_syria.csv")
country_conflict_years_df = pd.concat([country_conflict_years_df,syria_df])

# %%
country_conflict_years_df.sort_values(["year","conflict_name"],inplace=True)
country_conflict_years_df.reset_index(drop=True,inplace=True)
country_conflict_years_df.to_csv("output_data/country_conflict_years_df.csv")
