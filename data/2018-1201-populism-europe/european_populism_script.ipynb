# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import math
import datetime
import dateutil.parser
import time
import re
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sklearn
from tqdm import tqdm_notebook
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Step 1: import data for party vote shares and ideological positions ##

# %%
# Dataframe containing party vote shares in 2011-14 and 2015-18 election cycles
party_stats_df = pd.read_csv("source_data/parlgov_party_vote_shares.csv",encoding="cp1252")
party_stats_df.dropna(subset=["latest_election_share"],inplace=True)
party_stats_df = party_stats_df[~((party_stats_df["previous_election_share"] == 0) & (party_stats_df["latest_election_share"] == 0))]
party_stats_df["vote_share_change"] = party_stats_df["latest_election_share"] - party_stats_df["previous_election_share"]
party_stats_df
# Out:
#          country  party_id party_abbrev  \
# 0        Belgium       102           PS
# 1        Belgium       103          SPA
# 2        Belgium       104        ECOLO
# 3        Belgium       105        Groen
# 4        Belgium       106           MR
# 5        Belgium       107          VLD
# 6        Belgium       108          cdH
# 7        Belgium       109         CD&V
# 8        Belgium       110         N-VA
# 9        Belgium       111          FDF
# 10       Belgium       112           VB
# 11       Belgium       119         PVDA
# 12       Belgium       120           PP
# 13       Denmark       201           SD
# 14       Denmark       202           RV
# 15       Denmark       203           KF
# 16       Denmark       206           SF
# 17       Denmark       211            V
# 18       Denmark       213           EL
# 19       Denmark       215           DF
# 20       Denmark       217        FolkB
# 21       Denmark       218           LA
# 22       Germany       301          CDU
# 23       Germany       302          SPD
# 24       Germany       303          FDP
# 25       Germany       304       Grunen
# 26       Germany       306        Linke
# 27       Germany       308          CSU
# 28       Germany       309          NPD
# 29       Germany       310          AfD
# ..           ...       ...          ...
# 252      Croatia      3107        HDSSB
# 253      Croatia      3109          HSP
# 254      Croatia      3112        HL-SR
# 255      Croatia      3113       HSP-AS
# 256      Croatia      3114         ORaH
# 257       Turkey      3401          AKP
# 258       Turkey      3402          CHP
# 259       Turkey      3403          MHP
# 260       Turkey      3407          HDP
# 261       Norway      3501           AP
# 262       Norway      3502          FrP
# 263       Norway      3503            H
# 264       Norway      3504           SV
# 265       Norway      3505           Sp
# 266       Norway      3506          KrF
# 267       Norway      3507            V
# 268       Norway      3508          MDG
# 269  Switzerland      3601      SVP/UDC
# 270  Switzerland      3602        SP/PS
# 271  Switzerland      3603      FDP/PLR
# 272  Switzerland      3604      CVP/PVC
# 273  Switzerland      3605      GPS/PES
# 274  Switzerland      3606      GLP/PVL
# 275  Switzerland      3607      EVP/PEV
# 276  Switzerland      3608      EDU/UDF
# 277  Switzerland      3610          LdT
# 278  Switzerland      3611      CSP/PCS
# 279  Switzerland      3612          BDP
# 280        Malta      3701           PL
# 281        Malta      3702           PN
#
#                                     party_name_english  \
# 0                    Socialist Party\tParti Socialiste
# 1    Socialist Party Different\tSocialistische Part...
# 2                                         Ecolo\tEcolo
# 3                                         Green\tGroen
# 4            Reformist Movement\tMouvement Réformateur
# 5    Open Flemish Liberals and Democrats\tOpen Vlaa...
# 6    Humanist Democratic Centre\tCentre Démocrate H...
# 7    Christian Democratic and Flemish\tChristen-Dem...
# 8        New Flemish Alliance\tNieuw-Vlaamse Alliantie
# 9    Francophone Democratic Federalists\tFédéralist...
# 10                     Flemish Interest\tVlaams Belang
# 11   Workers’ Party of Belgium\tPartij van de Arbei...
# 12                     People’s Party\tParti Populaire
# 277  http://www.parlgov.org/explore/CHE/election/20...
# 278  http://www.parlgov.org/explore/CHE/election/20...
# 279  http://www.parlgov.org/explore/CHE/election/20...
# 280  http://www.parlgov.org/explore/mlt/election/20...
# 281  http://www.parlgov.org/explore/mlt/election/20...
#
#      previous_election_share previous_election_notes  \
# 0                       11.7                     NaN
# 1                        8.8                     NaN
# 2                        3.3                     NaN
# 3                        5.3                     NaN
# 4                        9.6                     NaN
# 5                        9.8                     NaN
# 6                        5.0                     NaN
# 7                       11.6                     NaN
# 8                       20.3                     NaN
# 9                        1.8                     NaN
# 10                       3.7                     NaN
# 11                       3.7                     NaN
# 12                       1.5                     NaN
# 13                      24.5                     NaN
# 14                       9.4                     NaN
# 15                       4.9                     NaN
# 16                       9.1                     NaN
# 17                      26.4                     NaN
# 18                       6.6                     NaN
# 19                      12.2                     NaN
# 20                       0.0                     NaN
# 21                       4.9                     NaN
# 22                      34.1                     NaN
# 23                      25.7                     NaN
# 24                       4.8                     NaN
# 25                       8.4                     NaN
# 26                       8.6                     NaN
# 27                       7.4                     NaN
# 28                       1.3                     NaN
# 29                       4.7                     NaN
# ..                       ...                     ...
# 252                      3.0                     NaN
# 253                      3.0                     NaN
# 254                      4.2                     NaN
# 255                      0.6                     NaN
# 256                      0.0                     NaN
# 257                     49.8                     NaN
# 258                     26.0                     NaN
# 259                     13.0                     NaN
# 260                      0.0                     NaN
# 261                     30.8                     NaN
# 262                     16.3                     NaN
# 263                     25.8                     NaN
# 264                      4.1                     NaN
# 265                      5.5                     NaN
# 266                      5.6                     NaN
# 267                      5.2                     NaN
# 268                      2.8                     NaN
# 269                     26.6                     NaN
# 270                     18.7                     NaN
# 271                     15.1                     NaN
# 272                     12.3                     NaN
# 273                      8.4                     NaN
# 274                      5.4                     NaN
# 275                      2.0                     NaN
# 276                      1.3                     NaN
# 277                      0.8                     NaN
# 278                      0.0                     NaN
# 279                      5.4                     NaN
# 280                     54.8                     NaN
# 281                     43.3                     NaN
#
#      previous_election_total_votes  previous_election_party_votes  \
# 0                          6744547                         789112
# 1                          6744547                         593520
# 2                          6744547                         222570
# 3                          6744547                         357461
# 4                          6744547                         647477
# 5                          6744547                         660966
# 6                          6744547                         337227
# 7                          6744547                         782367
# 8                          6744547                        1369143
# 9                          6744547                         121402
# 10                         6744547                         249548
# 11                         6744547                         249548
# 12                         6744547                         101168
# 13                         3545368                         868615
# 14                         3545368                         333265
# 15                         3545368                         173723
# 16                         3545368                         322628
# 17                         3545368                         935977
# 18                         3545368                         233994
# 19                         3545368                         432535
# 20                         3545368                              0
# 21                         3545368                         173723
# 22                        43726856                       14910858
# 23                        43726856                       11237802
# 24                        43726856                        2098889
# 25                        43726856                        3673056
# 26                        43726856                        3760510
# 27                        43726856                        3235787
# 28                        43726856                         568449
# 29                        43726856                        2055162
# ..                             ...                            ...
# 252                        2332604                          69978
# 253                        2332604                          69978
# 254                        2332604                          97969
# 255                        2332604                          13996
# 256                        2332604                              0
# 257                       42941763                       21384998
# 258                       42941763                       11164858
# 259                       42941763                        5582429
# 260                       42941763                              0
# 261                        2836029                         873497
# 262                        2836029                         462273
# 263                        2836029                         731695
# 264                        2836029                         116277
# 265                        2836029                         155982
# 266                        2836029                         158818
# 267                        2836029                         147474
# 268                        2836029                          79409
# 269                        2442648                         649744
# 270                        2442648                         456775
# 271                        2442648                         368840
# 272                        2442648                         300446
# 273                        2442648                         205182
# 274                        2442648                         131903
# 275                        2442648                          48853
# 276                        2442648                          31754
# 277                        2442648                          19541
# 278                        2442648                              0
# 279                        2442648                         131903
# 280                         305556                         167445
# 281                         305556                         132306
#
#      latest_election                             latest_election_source  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 7                NaN                                                NaN
# 8                NaN                                                NaN
# 9                NaN                                                NaN
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# 12               NaN                                                NaN
# 13            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 14            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 15            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 16            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 17            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 18            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 19            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 20            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 21            2015.0  http://www.parlgov.org/explore/DNK/election/20...
# 22            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 23            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 24            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 25            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 26            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 27            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 28            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# 29            2017.0  http://www.parlgov.org/explore/DEU/election/20...
# ..               ...                                                ...
# 252           2016.0  http://www.parlgov.org/explore/hrv/election/20...
# 253           2016.0  http://www.parlgov.org/explore/hrv/election/20...
# 254           2016.0  http://www.parlgov.org/explore/hrv/election/20...
# 255           2016.0  http://www.parlgov.org/explore/hrv/election/20...
# 256           2016.0  http://www.parlgov.org/explore/hrv/election/20...
# 257           2018.0  http://www.parlgov.org/explore/TUR/election/20...
# 258           2018.0  http://www.parlgov.org/explore/TUR/election/20...
# 259           2018.0  http://www.parlgov.org/explore/TUR/election/20...
# 260           2018.0  http://www.parlgov.org/explore/TUR/election/20...
# 261           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 262           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 263           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 264           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 265           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 266           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 267           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 268           2017.0  http://www.parlgov.org/explore/NOR/election/20...
# 269           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 270           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 271           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 272           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 273           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 274           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 275           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 276           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 277           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 278           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 279           2017.0  http://www.parlgov.org/explore/CHE/election/20...
# 280           2017.0  http://www.parlgov.org/explore/mlt/election/20...
# 281           2017.0  http://www.parlgov.org/explore/mlt/election/20...
#
#      latest_election_share latest_election_notes  last_election_total_votes  \
# 0                      NaN                   NaN                        NaN
# 1                      NaN                   NaN                        NaN
# 2                      NaN                   NaN                        NaN
# 3                      NaN                   NaN                        NaN
# 4                      NaN                   NaN                        NaN
# 5                      NaN                   NaN                        NaN
# 6                      NaN                   NaN                        NaN
# 7                      NaN                   NaN                        NaN
# 8                      NaN                   NaN                        NaN
# 9                      NaN                   NaN                        NaN
# 10                     NaN                   NaN                        NaN
# 11                     NaN                   NaN                        NaN
# 12                     NaN                   NaN                        NaN
# 13                    25.7                   NaN                  3560060.0
# 14                     4.5                   NaN                  3560060.0
# 15                     3.3                   NaN                  3560060.0
# 16                     4.1                   NaN                  3560060.0
# 17                    19.0                   NaN                  3560060.0
# 18                     7.6                   NaN                  3560060.0
# 19                    20.6                   NaN                  3560060.0
# 20                     0.0                   NaN                  3560060.0
# 21                     7.4                   NaN                  3560060.0
# 22                    26.8                   NaN                 46515492.0
# 23                    20.5                   NaN                 46515492.0
# 24                    10.7                   NaN                 46515492.0
# 25                     8.9                   NaN                 46515492.0
# 26                     9.2                   NaN                 46515492.0
# 27                     6.2                   NaN                 46515492.0
# 28                     0.0                   NaN                 46515492.0
# 29                    12.6                   NaN                 46515492.0
# ..                     ...                   ...                        ...
# 252                    1.2                   NaN                  1978298.0
# 253                    0.0                   NaN                  1978298.0
# 254                    0.0                   NaN                  1978298.0
# 255                    0.0                   NaN                  1978298.0
# 256                    0.0                   NaN                  1978298.0
# 257                   42.6                   NaN                 50059249.0
# 258                   22.7                   NaN                 50059249.0
# 259                   11.1                   NaN                 50059249.0
# 260                   11.7                   NaN                 50059249.0
# 261                   27.4                   NaN                  2921657.0
# 262                   15.2                   NaN                  2921657.0
# 263                   25.0                   NaN                  2921657.0
# 264                    6.0                   NaN                  2921657.0
# 265                   10.3                   NaN                  2921657.0
# 266                    4.2                   NaN                  2921657.0
# 267                    4.4                   NaN                  2921657.0
# 268                    3.2                   NaN                  2921657.0
# 269                   29.4                   NaN                  2521502.0
# 270                   18.8                   NaN                  2521502.0
# 271                   16.4                   NaN                  2521502.0
# 272                   11.7                   NaN                  2521502.0
# 273                    7.1                   NaN                  2521502.0
# 274                    4.6                   NaN                  2521502.0
# 275                    2.1                   NaN                  2521502.0
# 276                    0.0                   NaN                  2521502.0
# 277                    0.0                   NaN                  2521502.0
# 278                    0.0                   NaN                  2521502.0
# 279                    4.1                   NaN                  2521502.0
# 280                   55.0                   NaN                   310665.0
# 281                   43.7                   NaN                   310665.0
#
#      last_election_party_votes
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                    914935.0
# 14                    160203.0
# 15                    117482.0
# 16                    145962.0
# 17                    676411.0
# 18                    270565.0
# 19                    733372.0
# 20                         0.0
# 21                    263444.0
# 22                  12466152.0
# 23                   9535676.0
# 24                   4977158.0
# 25                   4139879.0
# 26                   4279425.0
# 27                   2883961.0
# 28                         0.0
# 29                   5860952.0
# ..                         ...
# 252                    23740.0
# 253                        0.0
# 254                        0.0
# 255                        0.0
# 256                        0.0
# 257                 21325240.0
# 258                 11363450.0
# 259                  5556577.0
# 260                  5856932.0
# 261                   800534.0
# 262                   444092.0
# 263                   730414.0
# 264                   175299.0
# 265                   300931.0
# 266                   122710.0
# 267                   128553.0
# 268                    93493.0
# 269                   741322.0
# 270                   474042.0
# 271                   413526.0
# 272                   295016.0
# 273                   179027.0
# 274                   115989.0
# 275                    52952.0
# 276                        0.0
# 277                        0.0
# 278                        0.0
# 279                   103382.0
# 280                   170866.0
# 281                   135761.0
#
# [282 rows x 16 columns]

# %%
# Dataframe containing party ideological ratings from Chapel-Hill Expert Survey
party_CHES_2014_df = pd.read_csv("source_data/CHES_2014_party_ideological_ratings.csv")
party_CHES_2017_df = pd.read_csv("source_data/CHES_2017_party_ideological_ratings.csv")

# %%
# Transform CHES rating on European integration, so that 0 = strongly in favour, 10 = strongly opposed
party_CHES_2014_df["EU_integration"] = 10 - (party_CHES_2014_df["eu_position"] - 1) * (10/6)
party_CHES_2017_df["EU_integration"] = 10 - (party_CHES_2017_df["position"] - 1) * (10/6)

# %% [markdown]
# ## Step 2: join CHES ratings onto vote share dataframe, and export

# %%
# CHES metrics to use for the analysis
metric_names = ["antielite_salience","EU_integration","immigrate_policy","galtan","lrecon"]

# %%
# Function that joins CHES ratings to party dataframe
def get_metric_info(metric):
    
    global party_stats_df
    
    metric_2014_list = []
    for i in party_stats_df["party_id"]:
        try:
            if int(i) in list(party_CHES_2014_df["party_id"]):
                metric_2014_list.append(party_CHES_2014_df[party_CHES_2014_df["party_id"]==i][metric].iloc[0])
            elif int(i) in list(party_CHES_2017_df["party_id"]):
                metric_2014_list.append(party_CHES_2017_df[party_CHES_2017_df["party_id"]==i][metric].iloc[0])
        except Exception:
            metric_2014_list.append(5.0)

    party_stats_df[metric+"_2014"] = metric_2014_list
                
    metric_2017_list = []
    for i in party_stats_df["party_id"]:
        try:
            if int(i) in list(party_CHES_2017_df["party_id"]):
                metric_2017_list.append(party_CHES_2017_df[party_CHES_2017_df["party_id"]==i][metric].iloc[0])
            elif int(i) in list(party_CHES_2014_df["party_id"]):
                metric_2017_list.append(party_CHES_2014_df[party_CHES_2014_df["party_id"]==i][metric].iloc[0])
        except Exception:
            metric_2017_list.append(5.0)

    party_stats_df[metric+"_2017"] = metric_2017_list

# %%
for m in metric_names:
    get_metric_info(m)

# %%
# Export merged dataframe
party_stats_df.to_csv("output_data/party_stats_df.csv")

# %% [markdown]
# ## Step 2: explore relationships between ideological positions and votes gained

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.suptitle("Relationship between votes gained and anti-elite salience",size=12,weight="bold")
plt.title("Using parties' CHES ideological ratings in 2017",size=10)
x = party_stats_df["antielite_salience_2017"]
y = party_stats_df["vote_share_change"]
ax.scatter(x,y)
ax.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color="black")
ax.set_xlabel("Anti-elite salience (0 = not important at all, 10 = very important)")
ax.set_ylabel("Change in vote share, 2011-14 to 2015-18")
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.suptitle("Relationship between votes gained and EU integration",size=12,weight="bold")
plt.title("Using parties' CHES ideological ratings in 2017",size=10)
x = party_stats_df["EU_integration_2017"]
y = party_stats_df["vote_share_change"]
ax.scatter(x,y)
ax.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color="black")
ax.set_xlabel("EU integration (0 = strongly in favour, 10 = strongly opposed)")
ax.set_ylabel("Change in vote share, 2011-14 to 2015-18")
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.suptitle("Relationship between votes gained and immigration policy",size=12,weight="bold")
plt.title("Using parties' CHES ideological ratings in 2017",size=10)
x = party_stats_df["immigrate_policy_2017"]
y = party_stats_df["vote_share_change"]
ax.scatter(x,y)
ax.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color="black")
ax.set_xlabel("Immigration (0 = oppose restrictions, 10 = support restrictions)")
ax.set_ylabel("Change in vote share, 2011-14 to 2015-18")
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.suptitle("Relationship between votes gained and civil liberties",size=12,weight="bold")
plt.title("Using parties' CHES ideological ratings in 2017",size=10)
x = party_stats_df["galtan_2017"]
y = party_stats_df["vote_share_change"]
ax.scatter(x,y)
ax.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color="black")
ax.set_xlabel("Civil liberties (0 = libertarian, 10 = authoritarian)")
ax.set_ylabel("Change in vote share, 2011-14 to 2015-18")
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5,5))
plt.suptitle("Relationship between votes gained and economic policy",size=12,weight="bold")
plt.title("Using parties' CHES ideological ratings in 2017",size=10)
x = party_stats_df["lrecon_2017"]
y = party_stats_df["vote_share_change"]
ax.scatter(x,y)
ax.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color="black")
ax.set_xlabel("Economic policy (0 = extreme left, 10 = extreme right)")
ax.set_ylabel("Change in vote share, 2011-14 to 2015-18")
plt.show()
